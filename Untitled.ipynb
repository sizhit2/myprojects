# %%
from flask import Flask,render_template,url_for,request
import os
from plotly.offline import iplot
import plotly.graph_objs as go
from flask import Markup
import flask
import pandas as pd 
import pickle
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np
import plotly.io as pio
import plotly

# %%
movie = pd.read_csv('data/movie.csv')
data_movie = movie['Combined']
with open('model.pkl','rb') as fid:
    model = pickle.load(fid)
with open('model_recommend.pkl','rb') as fid:
    vec = pickle.load(fid)

data_movie = movie['Combined']
message = 'hello'

data = vec.transform([message])

result = model.kneighbors(data)
info = []
labels = []
idx = []
scores = []
for i in result[1][0]:
    t = movie.iloc[i]['Title']
    if(pd.isna(t)):
        continue
    else:
        j = np.argwhere(result[1][0] == i)[0][0]
        if(result[0][0][j] != 1):
            l = [t,data_movie.iloc[i]]
            scores.append(movie['scores'].iloc[i])
            info.append([movie['scores'].iloc[i],movie['Genre'].iloc[i],l,movie['url'].iloc[i]])
            idx.append(j)
            labels.append(t)
values = (result[0][0])[idx] 
colors = ['#FEBFB3', '#E1396C', '#96D38C', '#D0F9B1','#A9D9B1']
trace = go.Pie(labels=labels, values=values,
       hoverinfo='label+percent', textinfo='value', 
       textfont=dict(size=20),
       marker=dict(colors=colors, 
                   line=dict(color='#000000', width=2)))

# %%
plotly.io.orca.config.executable = '/home/guangya/anaconda3/bin/orca'
plotly.io.orca.config.save() 
import matplotlib.pyplot as plt
from plotly import tools
df_action = movie[movie['Genre'].str.contains('Action') ]
info = []
info.append(len(df_action))
info.append(df_action['Cast 1'].value_counts().index[0])
info.append(df_action['Director 1'].value_counts().index[0])
info.append(df_action['Studio'].value_counts().index[0])
info.append([df_action['scores'].max(),df_action[df_action['scores'] == df_action['scores'].max()]])
info.append([df_action['scores'].min(),df_action[df_action['scores'] == df_action['scores'].min()]])
fig = tools.make_subplots(rows=2, cols=2,subplot_titles = ('Most Popular Actors','Most popular director','Most popular studio','Scores Distributio'))
actor = go.Bar(
            y=df_action['Cast 1'].value_counts()[:10],
            x=df_action['Cast 1'].value_counts()[:10].index[:10],
            text=df_action['Cast 1'].value_counts()[:10],
            textposition = 'auto',
            marker=dict(
                color='rgb(234,125,92)',
                line=dict(
                    color='rgb(8,48,107)',
                    width=1.5),
            ),
            name = 'Actor',
            opacity=0.6
        )
director = go.Bar(
            y=df_action['Director 1'].value_counts()[:10],
            x=df_action['Director 1'].value_counts()[:10].index[:10],
            text=df_action['Director 1'].value_counts()[:10],
            textposition = 'auto',
            marker=dict(
                color='rgb(119,174,103)',
                line=dict(
                    color='rgb(8,48,107)',
                    width=1.5),
            ),
    name = 'Director',
            opacity=0.6
        )
studio = go.Bar(
            y=df_action['Studio'].value_counts()[:10],
            x=df_action['Studio'].value_counts()[:10].index[:10],
            text=df_action['Studio'].value_counts()[:10],
            textposition = 'auto',
            marker=dict(
                color='rgb(204,106,118)',
                line=dict(
                    color='rgb(8,48,107)',
                    width=1.5),
            ),
    name = 'Studio',
            opacity=0.6
        )
score = go.Histogram(
            x=df_action['scores'],
            xbins=dict(
            start=0,
            end=10,
            size=0.5
        ),
            marker=dict(
                color='rgb(103,162,178)',
                line=dict(
                    color='rgb(8,48,107)',
                    width=1.5),
            ),
    name = 'Score',
            opacity=0.6
        )

fig.append_trace(actor, 1, 1)
fig.append_trace(director, 1, 2)
fig.append_trace(studio, 2, 1)
fig.append_trace(score, 2, 2)
fig['layout'].update(height=1600, width=1000, title='Information about Action movie')
iplot(fig)
pio.write_image(fig, 'static/img/action.png')
# Out:
# This is the format of your plot grid:
# [ (1,1) x1,y1 ]  [ (1,2) x2,y2 ]
# [ (2,1) x3,y3 ]  [ (2,2) x4,y4 ]

# %%
df_comedy = 
df_action =df_comedy
info = []
info.append(len(df_action))
info.append(df_action['Cast 1'].value_counts().index[0])
info.append(df_action['Director 1'].value_counts().index[0])
info.append(df_action['Studio'].value_counts().index[0])
info.append([df_action['scores'].max(),df_action[df_action['scores'] == df_action['scores'].max()]])
info.append([df_action['scores'].min(),df_action[df_action['scores'] == df_action['scores'].min()]])
fig = tools.make_subplots(rows=2, cols=2,subplot_titles = ('Most Popular Actors','Most popular director','Most popular studio','Scores Distributio'))
actor = go.Bar(
            y=df_action['Cast 1'].value_counts()[:10],
            x=df_action['Cast 1'].value_counts()[:10].index[:10],
            text=df_action['Cast 1'].value_counts()[:10],
            textposition = 'auto',
            marker=dict(
                color='rgb(234,125,92)',
                line=dict(
                    color='rgb(8,48,107)',
                    width=1.5),
            ),
            name = 'Actor',
            opacity=0.6
        )
director = go.Bar(
            y=df_action['Director 1'].value_counts()[:10],
            x=df_action['Director 1'].value_counts()[:10].index[:10],
            text=df_action['Director 1'].value_counts()[:10],
            textposition = 'auto',
            marker=dict(
                color='rgb(119,174,103)',
                line=dict(
                    color='rgb(8,48,107)',
                    width=1.5),
            ),
    name = 'Director',
            opacity=0.6
        )
studio = go.Bar(
            y=df_action['Studio'].value_counts()[:10],
            x=df_action['Studio'].value_counts()[:10].index[:10],
            text=df_action['Studio'].value_counts()[:10],
            textposition = 'auto',
            marker=dict(
                color='rgb(204,106,118)',
                line=dict(
                    color='rgb(8,48,107)',
                    width=1.5),
            ),
    name = 'Studio',
            opacity=0.6
        )
score = go.Histogram(
            x=df_action['scores'],
            xbins=dict(
            start=0,
            end=10,
            size=0.5
        ),
            marker=dict(
                color='rgb(103,162,178)',
                line=dict(
                    color='rgb(8,48,107)',
                    width=1.5),
            ),
    name = 'Score',
            opacity=0.6
        )

fig.append_trace(actor, 1, 1)
fig.append_trace(director, 1, 2)
fig.append_trace(studio, 2, 1)
fig.append_trace(score, 2, 2)
fig['layout'].update(height=1600, width=1000, title='Information about Action movie')
iplot(fig)
pio.write_image(fig, 'static/img/comedy.png')
# Out:
# This is the format of your plot grid:
# [ (1,1) x1,y1 ]  [ (1,2) x2,y2 ]
# [ (2,1) x3,y3 ]  [ (2,2) x4,y4 ]

# %%
df_docu = movie[movie['Genre'].str.contains('Documentary')]
plt.figure(figsize=(30,20))
df_action = df_docu
df_action.replace('  ','Not Available',inplace = True)
info = []
info.append(len(df_action))
info.append(df_action['Cast 1'].value_counts().index[1])
info.append(df_action['Director 1'].value_counts().index[1])
info.append(df_action['Studio'].value_counts().index[0])
info.append([df_action['scores'].max(),df_action[df_action['scores'] == df_action['scores'].max()]])
info.append([df_action['scores'].min(),df_action[df_action['scores'] == df_action['scores'].min()]])
fig = tools.make_subplots(rows=2, cols=2,subplot_titles = ('Most Popular Actors','Most popular director','Most popular studio','Scores Distributio'))
actor = go.Bar(
            y=df_action['Cast 1'].value_counts()[:10],
            x=df_action['Cast 1'].value_counts()[:10].index[:10],
            text=df_action['Cast 1'].value_counts()[:10],
            textposition = 'auto',
            marker=dict(
                color='rgb(234,125,92)',
                line=dict(
                    color='rgb(8,48,107)',
                    width=1.5),
            ),
            name = 'Actor',
            opacity=0.6
        )
director = go.Bar(
            y=df_action['Director 1'].value_counts()[:10],
            x=df_action['Director 1'].value_counts()[:10].index[:10],
            text=df_action['Director 1'].value_counts()[:10],
            textposition = 'auto',
            marker=dict(
                color='rgb(119,174,103)',
                line=dict(
                    color='rgb(8,48,107)',
                    width=1.5),
            ),
    name = 'Director',
            opacity=0.6
        )
studio = go.Bar(
            y=df_action['Studio'].value_counts()[:10],
            x=df_action['Studio'].value_counts()[:10].index[:10],
            text=df_action['Studio'].value_counts()[:10],
            textposition = 'auto',
            marker=dict(
                color='rgb(204,106,118)',
                line=dict(
                    color='rgb(8,48,107)',
                    width=1.5),
            ),
    name = 'Studio',
            opacity=0.6
        )
score = go.Histogram(
            x=df_action['scores'],
            xbins=dict(
            start=0,
            end=10,
            size=0.5
        ),
            marker=dict(
                color='rgb(103,162,178)',
                line=dict(
                    color='rgb(8,48,107)',
                    width=1.5),
            ),
    name = 'Score',
            opacity=0.6
        )

fig.append_trace(actor, 1, 1)
fig.append_trace(director, 1, 2)
fig.append_trace(studio, 2, 1)
fig.append_trace(score, 2, 2)
fig['layout'].update(height=1600, width=1000, title='Information about Documentary movie')
iplot(fig)
pio.write_image(fig, 'static/img/docu.png')
# Out:
# This is the format of your plot grid:
# [ (1,1) x1,y1 ]  [ (1,2) x2,y2 ]
# [ (2,1) x3,y3 ]  [ (2,2) x4,y4 ]
# /home/guangya/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:4042: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_mystery = movie[movie['Genre'].str.contains('Mystery') ]
plt.figure(figsize=(30,20))
df_action =df_mystery
df_action.replace('  ','Not Available',inplace = True)
info = []
info.append(len(df_action))
info.append(df_action['Cast 1'].value_counts().index[0])
info.append(df_action['Director 1'].value_counts().index[0])
info.append(df_action['Studio'].value_counts().index[0])
info.append([df_action['scores'].max(),df_action[df_action['scores'] == df_action['scores'].max()]])
info.append([df_action['scores'].min(),df_action[df_action['scores'] == df_action['scores'].min()]])
fig = tools.make_subplots(rows=2, cols=2,subplot_titles = ('Most Popular Actors','Most popular director','Most popular studio','Scores Distributio'))
actor = go.Bar(
            y=df_action['Cast 1'].value_counts()[:10],
            x=df_action['Cast 1'].value_counts()[:10].index[:10],
            text=df_action['Cast 1'].value_counts()[:10],
            textposition = 'auto',
            marker=dict(
                color='rgb(234,125,92)',
                line=dict(
                    color='rgb(8,48,107)',
                    width=1.5),
            ),
            name = 'Actor',
            opacity=0.6
        )
director = go.Bar(
            y=df_action['Director 1'].value_counts()[:10],
            x=df_action['Director 1'].value_counts()[:10].index[:10],
            text=df_action['Director 1'].value_counts()[:10],
            textposition = 'auto',
            marker=dict(
                color='rgb(119,174,103)',
                line=dict(
                    color='rgb(8,48,107)',
                    width=1.5),
            ),
    name = 'Director',
            opacity=0.6
        )
studio = go.Bar(
            y=df_action['Studio'].value_counts()[:10],
            x=df_action['Studio'].value_counts()[:10].index[:10],
            text=df_action['Studio'].value_counts()[:10],
            textposition = 'auto',
            marker=dict(
                color='rgb(204,106,118)',
                line=dict(
                    color='rgb(8,48,107)',
                    width=1.5),
            ),
    name = 'Studio',
            opacity=0.6
        )
score = go.Histogram(
            x=df_action['scores'],
            xbins=dict(
            start=0,
            end=10,
            size=0.5
        ),
            marker=dict(
                color='rgb(103,162,178)',
                line=dict(
                    color='rgb(8,48,107)',
                    width=1.5),
            ),
    name = 'Score',
            opacity=0.6
        )

fig.append_trace(actor, 1, 1)
fig.append_trace(director, 1, 2)
fig.append_trace(studio, 2, 1)
fig.append_trace(score, 2, 2)
fig['layout'].update(height=1600, width=1000, title='Information about Mystery/Thriller movie')
iplot(fig)
pio.write_image(fig, 'static/img/mystery.png')
# Out:
# This is the format of your plot grid:
# [ (1,1) x1,y1 ]  [ (1,2) x2,y2 ]
# [ (2,1) x3,y3 ]  [ (2,2) x4,y4 ]

# %%
df_romance = movie[movie['Genre'].str.contains('Romance') ]
plt.figure(figsize=(30,20))
df_action =df_romance
df_action.replace('  ','Not Available',inplace = True)
info = []
info.append(len(df_action))
info.append(df_action['Cast 1'].value_counts().index[0])
info.append(df_action['Director 1'].value_counts().index[0])
info.append(df_action['Studio'].value_counts().index[0])
info.append([df_action['scores'].max(),df_action[df_action['scores'] == df_action['scores'].max()]])
info.append([df_action['scores'].min(),df_action[df_action['scores'] == df_action['scores'].min()]])
fig = tools.make_subplots(rows=2, cols=2,subplot_titles = ('Most Popular Actors','Most popular director','Most popular studio','Scores Distributio'))
actor = go.Bar(
            y=df_action['Cast 1'].value_counts()[:10],
            x=df_action['Cast 1'].value_counts()[:10].index[:10],
            text=df_action['Cast 1'].value_counts()[:10],
            textposition = 'auto',
            marker=dict(
                color='rgb(234,125,92)',
                line=dict(
                    color='rgb(8,48,107)',
                    width=1.5),
            ),
            name = 'Actor',
            opacity=0.6
        )
director = go.Bar(
            y=df_action['Director 1'].value_counts()[:10],
            x=df_action['Director 1'].value_counts()[:10].index[:10],
            text=df_action['Director 1'].value_counts()[:10],
            textposition = 'auto',
            marker=dict(
                color='rgb(119,174,103)',
                line=dict(
                    color='rgb(8,48,107)',
                    width=1.5),
            ),
    name = 'Director',
            opacity=0.6
        )
studio = go.Bar(
            y=df_action['Studio'].value_counts()[:10],
            x=df_action['Studio'].value_counts()[:10].index[:10],
            text=df_action['Studio'].value_counts()[:10],
            textposition = 'auto',
            marker=dict(
                color='rgb(204,106,118)',
                line=dict(
                    color='rgb(8,48,107)',
                    width=1.5),
            ),
    name = 'Studio',
            opacity=0.6
        )
score = go.Histogram(
            x=df_action['scores'],
            xbins=dict(
            start=0,
            end=10,
            size=0.5
        ),
            marker=dict(
                color='rgb(103,162,178)',
                line=dict(
                    color='rgb(8,48,107)',
                    width=1.5),
            ),
    name = 'Score',
            opacity=0.6
        )
fig.append_trace(actor, 1, 1)
fig.append_trace(director, 1, 2)
fig.append_trace(studio, 2, 1)
fig.append_trace(score, 2, 2)
fig['layout'].update(height=1600, width=1000, title='Information about Romantic movie')
iplot(fig)
pio.write_image(fig, 'static/img/action.png')
# Out:
# This is the format of your plot grid:
# [ (1,1) x1,y1 ]  [ (1,2) x2,y2 ]
# [ (2,1) x3,y3 ]  [ (2,2) x4,y4 ]
# /home/guangya/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:4042: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_drama = movie[movie['Genre'].str.contains('Drama')]
plt.figure(figsize=(30,20))
df_action =df_drama
df_action.replace('  ','Not Available',inplace = True)
info = []
info.append(len(df_action))
info.append(df_action['Cast 1'].value_counts().index[1])
info.append(df_action['Director 1'].value_counts().index[0])
info.append(df_action['Studio'].value_counts().index[0])
info.append([df_action['scores'].max(),df_action[df_action['scores'] == df_action['scores'].max()]])
info.append([df_action['scores'].min(),df_action[df_action['scores'] == df_action['scores'].min()]])
fig = tools.make_subplots(rows=2, cols=2,subplot_titles = ('Most Popular Actors','Most popular director','Most popular studio','Scores Distributio'))
actor = go.Bar(
            y=df_action['Cast 1'].value_counts()[:10],
            x=df_action['Cast 1'].value_counts()[:10].index[:10],
            text=df_action['Cast 1'].value_counts()[:10],
            textposition = 'auto',
            marker=dict(
                color='rgb(234,125,92)',
                line=dict(
                    color='rgb(8,48,107)',
                    width=1.5),
            ),
            name = 'Actor',
            opacity=0.6
        )
director = go.Bar(
            y=df_action['Director 1'].value_counts()[:10],
            x=df_action['Director 1'].value_counts()[:10].index[:10],
            text=df_action['Director 1'].value_counts()[:10],
            textposition = 'auto',
            marker=dict(
                color='rgb(119,174,103)',
                line=dict(
                    color='rgb(8,48,107)',
                    width=1.5),
            ),
    name = 'Director',
            opacity=0.6
        )
studio = go.Bar(
            y=df_action['Studio'].value_counts()[:10],
            x=df_action['Studio'].value_counts()[:10].index[:10],
            text=df_action['Studio'].value_counts()[:10],
            textposition = 'auto',
            marker=dict(
                color='rgb(204,106,118)',
                line=dict(
                    color='rgb(8,48,107)',
                    width=1.5),
            ),
    name = 'Studio',
            opacity=0.6
        )
score = go.Histogram(
            x=df_action['scores'],
            xbins=dict(
            start=0,
            end=10,
            size=0.5
        ),
            marker=dict(
                color='rgb(103,162,178)',
                line=dict(
                    color='rgb(8,48,107)',
                    width=1.5),
            ),
    name = 'Score',
            opacity=0.6
        )

fig.append_trace(actor, 1, 1)
fig.append_trace(director, 1, 2)
fig.append_trace(studio, 2, 1)
fig.append_trace(score, 2, 2)
fig['layout'].update(height=1600, width=1000, title='Information about Drama movie')
iplot(fig)
# Out:
# This is the format of your plot grid:
# [ (1,1) x1,y1 ]  [ (1,2) x2,y2 ]
# [ (2,1) x3,y3 ]  [ (2,2) x4,y4 ]
# /home/guangya/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:4042: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_scifi = movie[movie['Genre'].str.contains('SciFi')]
plt.figure(figsize=(30,20))
df_action =df_scifi
df_action.replace('  ','Not Available',inplace = True)
info = []
info.append(len(df_action))
info.append(df_action['Cast 1'].value_counts().index[0])
info.append(df_action['Director 1'].value_counts().index[0])
info.append(df_action['Studio'].value_counts().index[0])
info.append([df_action['scores'].max(),df_action[df_action['scores'] == df_action['scores'].max()]])
info.append([df_action['scores'].min(),df_action[df_action['scores'] == df_action['scores'].min()]])
fig = tools.make_subplots(rows=2, cols=2,subplot_titles = ('Most Popular Actors','Most popular director','Most popular studio','Scores Distributio'))
actor = go.Bar(
            y=df_action['Cast 1'].value_counts()[:10],
            x=df_action['Cast 1'].value_counts()[:10].index[:10],
            text=df_action['Cast 1'].value_counts()[:10],
            textposition = 'auto',
            marker=dict(
                color='rgb(234,125,92)',
                line=dict(
                    color='rgb(8,48,107)',
                    width=1.5),
            ),
            name = 'Actor',
            opacity=0.6
        )
director = go.Bar(
            y=df_action['Director 1'].value_counts()[:10],
            x=df_action['Director 1'].value_counts()[:10].index[:10],
            text=df_action['Director 1'].value_counts()[:10],
            textposition = 'auto',
            marker=dict(
                color='rgb(119,174,103)',
                line=dict(
                    color='rgb(8,48,107)',
                    width=1.5),
            ),
    name = 'Director',
            opacity=0.6
        )
studio = go.Bar(
            y=df_action['Studio'].value_counts()[:10],
            x=df_action['Studio'].value_counts()[:10].index[:10],
            text=df_action['Studio'].value_counts()[:10],
            textposition = 'auto',
            marker=dict(
                color='rgb(204,106,118)',
                line=dict(
                    color='rgb(8,48,107)',
                    width=1.5),
            ),
    name = 'Studio',
            opacity=0.6
        )
score = go.Histogram(
            x=df_action['scores'],
            xbins=dict(
            start=0,
            end=10,
            size=0.5
        ),
            marker=dict(
                color='rgb(103,162,178)',
                line=dict(
                    color='rgb(8,48,107)',
                    width=1.5),
            ),
    name = 'Score',
            opacity=0.6
        )

fig.append_trace(actor, 1, 1)
fig.append_trace(director, 1, 2)
fig.append_trace(studio, 2, 1)
fig.append_trace(score, 2, 2)
fig['layout'].update(height=1600, width=1000, title='Information about Science Fiction movie')
iplot(fig)
# Out:
# This is the format of your plot grid:
# [ (1,1) x1,y1 ]  [ (1,2) x2,y2 ]
# [ (2,1) x3,y3 ]  [ (2,2) x4,y4 ]

# %%
info
# Out:
# [1679,
#  'Nicolas Cage  ',
#  'Peter Jackson  ',
#  'Warner Bros. Pictures  ',
#  [9.5,
#                    Cast 1            Cast 2        Cast 3         Cast 4  \
#   12634  Patrik Karlson    Johanna Tschig    Per Lfberg    Ahnna Rasch
#
#                    Cast 5         Cast 6  \
#   12634  Lukas Loughran    Not Available
#
#                                                Description        Director 1  \
#   12634  Robert, a loner whose sole passion in life is ...  Antonio Tublen
#
#             Director 2     Director 3            Studio             Title  \
#   12634  Not Available  Not Available  Dark Sky Films    LFO: The Movie
#
#                  Writer 1       Writer 2       Writer 3       Writer 4  \
#   12634  Antonio Tublen    Not Available  Not Available  Not Available
#
#                   Genre                                           Combined  \
#   12634  Drama  SciFi    Patrik Karlson  Johanna Tschig  Per Lfberg  Ah...
#
#                                                        url  scores
#   12634  https://www.imdb.com/title/tt6290024/?ref_=fn_...     9.5  ],
#  [2.2,
#                  Cast 1          Cast 2         Cast 3            Cast 4  \
#   7591  Jamie Kennedy    Alan Cumming    Bob Hoskins    Traylor Howard
#
#              Cast 5           Cast 6  \
#   7591  Ben Stein    Steven Wright
#
#                                               Description           Director 1  \
#   7591  Just as aspiring cartoonist Tim Avery gets ove...  Lawrence Guterman
#
#            Director 2     Director 3             Studio              Title  \
#   7591  Not Available  Not Available  New Line Cinema    Son of the Mask
#
#               Writer 1       Writer 2       Writer 3       Writer 4  \
#   7591  Lance Khazei    Not Available  Not Available  Not Available
#
#                   Genre                                           Combined  \
#   7591  SciFi  Comedy    Jamie Kennedy  Alan Cumming  Bob Hoskins  Tray...
#
#                                                       url  scores
#   7591  https://www.imdb.com/title/tt0362165/?ref_=fn_...     2.2  ]]

# %%
df_class = movie[movie['Genre'].str.contains('Classics')]
plt.figure(figsize=(30,20))
df_action =df_class
df_action.replace('  ','Not Available',inplace = True)
info = []
info.append(len(df_action))
info.append(df_action['Cast 1'].value_counts().index[0])
info.append(df_action['Director 1'].value_counts().index[0])
info.append(df_action['Studio'].value_counts().index[0])
info.append([df_action['scores'].max(),df_action[df_action['scores'] == df_action['scores'].max()]])
info.append([df_action['scores'].min(),df_action[df_action['scores'] == df_action['scores'].min()]])
fig = tools.make_subplots(rows=2, cols=2,subplot_titles = ('Most Popular Actors','Most popular director','Most popular studio','Scores Distributio'))
actor = go.Bar(
            y=df_action['Cast 1'].value_counts()[:10],
            x=df_action['Cast 1'].value_counts()[:10].index[:10],
            text=df_action['Cast 1'].value_counts()[:10],
            textposition = 'auto',
            marker=dict(
                color='rgb(234,125,92)',
                line=dict(
                    color='rgb(8,48,107)',
                    width=1.5),
            ),
            name = 'Actor',
            opacity=0.6
        )
director = go.Bar(
            y=df_action['Director 1'].value_counts()[:10],
            x=df_action['Director 1'].value_counts()[:10].index[:10],
            text=df_action['Director 1'].value_counts()[:10],
            textposition = 'auto',
            marker=dict(
                color='rgb(119,174,103)',
                line=dict(
                    color='rgb(8,48,107)',
                    width=1.5),
            ),
    name = 'Director',
            opacity=0.6
        )
studio = go.Bar(
            y=df_action['Studio'].value_counts()[:10],
            x=df_action['Studio'].value_counts()[:10].index[:10],
            text=df_action['Studio'].value_counts()[:10],
            textposition = 'auto',
            marker=dict(
                color='rgb(204,106,118)',
                line=dict(
                    color='rgb(8,48,107)',
                    width=1.5),
            ),
    name = 'Studio',
            opacity=0.6
        )
score = go.Histogram(
            x=df_action['scores'],
            xbins=dict(
            start=0,
            end=10,
            size=0.5
        ),
            marker=dict(
                color='rgb(103,162,178)',
                line=dict(
                    color='rgb(8,48,107)',
                    width=1.5),
            ),
    name = 'Score',
            opacity=0.6
        )

fig.append_trace(actor, 1, 1)
fig.append_trace(director, 1, 2)
fig.append_trace(studio, 2, 1)
fig.append_trace(score, 2, 2)
fig['layout'].update(height=1600, width=1000, title='Information about Classic movie')
iplot(fig)
# Out:
# /home/guangya/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:4042: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# This is the format of your plot grid:
# [ (1,1) x1,y1 ]  [ (1,2) x2,y2 ]
# [ (2,1) x3,y3 ]  [ (2,2) x4,y4 ]

# %%
plt.figure(figsize=(30,20))
df_action =movie
df_action.replace('  ','Not Available',inplace = True)
info = []
info.append(len(df_action))
info.append(df_action['Cast 1'].value_counts().index[1])
info.append(df_action['Director 1'].value_counts().index[1])
info.append(df_action['Studio'].value_counts().index[0])
info.append([df_action['scores'].max(),df_action[df_action['scores'] == df_action['scores'].max()]])
info.append([df_action['scores'].min(),df_action[df_action['scores'] == df_action['scores'].min()]])
fig = tools.make_subplots(rows=2, cols=2,subplot_titles = ('Most Popular Actors','Most popular director','Most popular studio','Scores Distributio'))
actor = go.Bar(
            y=df_action['Cast 1'].value_counts()[:10],
            x=df_action['Cast 1'].value_counts()[:10].index[:10],
            text=df_action['Cast 1'].value_counts()[:10],
            textposition = 'auto',
            marker=dict(
                color='rgb(234,125,92)',
                line=dict(
                    color='rgb(8,48,107)',
                    width=1.5),
            ),
            name = 'Actor',
            opacity=0.6
        )
director = go.Bar(
            y=df_action['Director 1'].value_counts()[:10],
            x=df_action['Director 1'].value_counts()[:10].index[:10],
            text=df_action['Director 1'].value_counts()[:10],
            textposition = 'auto',
            marker=dict(
                color='rgb(119,174,103)',
                line=dict(
                    color='rgb(8,48,107)',
                    width=1.5),
            ),
    name = 'Director',
            opacity=0.6
        )
studio = go.Bar(
            y=df_action['Studio'].value_counts()[:10],
            x=df_action['Studio'].value_counts()[:10].index[:10],
            text=df_action['Studio'].value_counts()[:10],
            textposition = 'auto',
            marker=dict(
                color='rgb(204,106,118)',
                line=dict(
                    color='rgb(8,48,107)',
                    width=1.5),
            ),
    name = 'Studio',
            opacity=0.6
        )
score = go.Histogram(
            x=df_action['scores'],
            xbins=dict(
            start=0,
            end=10,
            size=0.5
        ),
            marker=dict(
                color='rgb(103,162,178)',
                line=dict(
                    color='rgb(8,48,107)',
                    width=1.5),
            ),
    name = 'Score',
            opacity=0.6
        )

fig.append_trace(actor, 1, 1)
fig.append_trace(director, 1, 2)
fig.append_trace(studio, 2, 1)
fig.append_trace(score, 2, 2)
fig['layout'].update(height=1600, width=1000, title='Information about ALL movies in our dataset')
iplot(fig)
# Out:
# This is the format of your plot grid:
# [ (1,1) x1,y1 ]  [ (1,2) x2,y2 ]
# [ (2,1) x3,y3 ]  [ (2,2) x4,y4 ]

# %%
info[4][1]['Cast 1'].iloc[0]
# Out:
# 'Kenneth More  '

# %%
info[4][1]
# Out:
#              Cast 1          Cast 2            Cast 3            Cast 4  \
# 686  Kenneth More    Ronald Allen    Honor Blackman    David McCallum
#
#              Cast 5             Cast 6  \
# 686  Robert Ayres    Anthony Bushell
#
#                                            Description        Director 1  \
# 686  This meticulous re-creation of the sinking of ...  Roy Ward Baker
#
#         Director 2     Director 3                  Studio  \
# 686  Not Available  Not Available  Criterion Collection
#
#                      Title       Writer 1       Writer 2       Writer 3  \
# 686  A Night to Remember    Eric Ambler    Not Available  Not Available
#
#           Writer 4               Genre  \
# 686  Not Available  Action  Classics
#
#                                               Combined  \
# 686  Kenneth More  Ronald Allen  Honor Blackman  Da...
#
#                                                    url  scores
# 686  https://www.imdb.com/title/tt5091902/?ref_=fn_...     9.9

# %%
x = []
x.append([df_action.sort_values(by='scores')[::-1][:10])
# Out:
# Drama                                                          1819
# Documentary                                                    1276
# Comedy                                                          918
# Drama  Art&Foreign                                              620
# Drama  Mystery                                                  617
# Drama  Comedy                                                   603
# Horror                                                          362
# Action  Drama                                                   353
# Drama  Romance                                                  342
# Action                                                          281
# Mystery  Action  Drama                                          281
# Mystery  Horror                                                 267
# Mystery                                                         224
# Drama  Classics                                                 221
# Romance  Comedy                                                 218
# Drama  Romance  Comedy                                          212
# Action  Mystery                                                 211
# Drama  Art&Foreign  Comedy                                      203
# Action  SciFi                                                   185
# Kids&Family                                                     143
# Mystery  Drama  Horror                                          141
# Action  Comedy                                                  140
# Kids&Family  Comedy                                             140
# Documentary  Drama                                              133
# Drama  Mystery  Art&Foreign                                     130
# Action  Drama  Classics                                         111
# Drama  Romance  Art&Foreign                                     110
# Romance                                                         109
# Drama  Mystery  Classics                                        106
# Action  Drama  Art&Foreign                                      101
#                                                                ...
# Drama  Romance  Kids&Family  Art&Foreign                          1
# Comedy  Action  Mystery  SciFi  Art&Foreign                       1
# Drama  Classics  Action  Mystery  SciFi                           1
# Documentary  Drama  Kids&Family  Art&Foreign                      1
# Drama  Comedy  SciFi  Horror  Art&Foreign                         1
# Drama  Documentary  Comedy  Kids&Family  Art&Foreign              1
# Mystery  Documentary  Horror                                      1
# Action  SciFi  Romance  Kids&Family                               1
# Documentary  Drama  Horror                                        1
# Drama  Classics  Comedy  SciFi  Kids&Family                       1
# SciFi  Action  Classics  Art&Foreign                              1
# Comedy  Action  Romance  Kids&Family                              1
# Action  Kids&Family  Art&Foreign  Comedy                          1
# Mystery  Horror  Kids&Family  Classics                            1
# Action  SciFi  Mystery  Classics                                  1
# Comedy  Action  Mystery  Horror                                   1
# Documentary  Classics  Art&Foreign  Comedy                        1
# Action  Romance  Art&Foreign  Comedy                              1
# Drama  Comedy  Action  SciFi  Art&Foreign                         1
# Drama  Documentary  Comedy  Action  Art&Foreign                   1
# Drama  Documentary  Classics  Comedy  Action  Art&Foreign         1
# Documentary  SciFi  Kids&Family  Art&Foreign                      1
# Romance  Kids&Family  Classics  Comedy                            1
# Drama  Classics  Action  SciFi  Horror                            1
# Mystery  Romance  Art&Foreign  Comedy                             1
# Drama  Comedy  Mystery  SciFi  Horror                             1
# Action  Kids&Family  Classics  Comedy                             1
# Drama  Documentary  Action  Mystery  SciFi                        1
# Action  SciFi  Mystery  Comedy                                    1
# Action  nanDrama  Art&Foreign                                     1
# Name: Genre, Length: 503, dtype: int64

# %%
x[0]
# Out:
#                     Cast 1                  Cast 2              Cast 3  \
# 12634     Patrik Karlson          Johanna Tschig          Per Lfberg
# 1586      Christian Bale            Heath Ledger       Aaron Eckhart
# 2318         Elijah Wood              Sean Astin        Ian McKellen
# 1711         Elijah Wood            Ian McKellen     Viggo Mortensen
# 1609   Leonardo DiCaprio    Joseph Gordon-Levitt          Ellen Page
# 1183    Richard Benjamin            James Brolin         Yul Brynner
# 255          Elijah Wood            Ian McKellen     Viggo Mortensen
# 915         Keanu Reeves      Laurence Fishburne    Carrie-Anne Moss
# 927          Ben Affleck         Jennifer Garner       Colin Farrell
# 1879         Mark Hamill           Harrison Ford       Carrie Fisher
#
#                         Cast 4              Cast 5             Cast 6  \
# 12634            Ahnna Rasch      Lukas Loughran        Not Available
# 1586       Maggie Gyllenhaal         Gary Oldman     Morgan Freeman
# 2318             Andy Serkis     Viggo Mortensen      Orlando Bloom
# 1711               Liv Tyler           Sean Bean     Cate Blanchett
# 1609               Tom Hardy        Ken Watanabe         Dileep Rao
# 1183             Linda Scott    Alan Oppenheimer     Norman Bartold
# 255               Sean Astin           Liv Tyler     Cate Blanchett
# 915           Joe Pantoliano        Hugo Weaving    Belinda McClory
# 927    Michael Clarke Duncan         Jon Favreau        Scott Terra
# 1879           Alec Guinness        David Prowse    Anthony Daniels
#
#                                              Description  \
# 12634  Robert, a loner whose sole passion in life is ...
# 1586   Christopher Nolan steps back into the director...
# 2318   The final battle for Middle-earth begins. Frod...
# 1711   Assisted by a Fellowship of heroes, Frodo Bagg...
# 1609   Visionary filmmaker Christopher Nolan (Memento...
# 1183   Welcome to Westworld, where nothing can go wro...
# 255    Frodo and Samwise press on toward Mordor. Goll...
# 915    What if virtual reality wasn't just for fun, b...
# 927    One of Marvel Comics' most popular characters ...
# 1879   The second entry in George Lucas' Star Wars tr...
#
#                      Director 1         Director 2        Director 3  \
# 12634          Antonio Tublen        Not Available     Not Available
# 1586        Christopher Nolan        Not Available     Not Available
# 2318            Peter Jackson        Not Available     Not Available
# 1711            Peter Jackson        Not Available     Not Available
# 1609        Christopher Nolan        Not Available     Not Available
# 1183         Michael Crichton        Not Available     Not Available
# 255             Peter Jackson        Not Available     Not Available
# 915    The Wachowski Brothers    Lilly Wachowski    Lana Wachowski
# 927       Mark Steven Johnson        Not Available     Not Available
# 1879           Irvin Kershner        Not Available     Not Available
#
#                                   Studio  \
# 12634                   Dark Sky Films
# 1586   Warner Bros. Pictures/Legendary
# 2318                   New Line Cinema
# 1711                   New Line Cinema
# 1609             Warner Bros. Pictures
# 1183                               MGM
# 255                    New Line Cinema
# 915              Warner Bros. Pictures
# 927                   20th Century Fox
# 1879             Twentieth Century Fox
#
#                                                    Title  \
# 12634                                   LFO: The Movie
# 1586                                   The Dark Knight
# 2318     The Lord of the Rings: The Return of the King
# 1711   The Lord of the Rings: The Fellowship of the R...
# 1609                                         Inception
# 1183                                         Westworld
# 255              The Lord of the Rings: The Two Towers
# 915                                         The Matrix
# 927                                          Daredevil
# 1879    Star Wars: Episode V - The Empire Strikes Back
#
#                     Writer 1            Writer 2           Writer 3  \
# 12634       Antonio Tublen         Not Available      Not Available
# 1586     Christopher Nolan      Jonathan Nolan        Not Available
# 2318            Fran Walsh     Philippa Boyens      Peter Jackson
# 1711            Fran Walsh       Peter Jackson    Philippa Boyens
# 1609     Christopher Nolan         Not Available      Not Available
# 1183      Michael Crichton         Not Available      Not Available
# 255        Philippa Boyens    Stephen Sinclair         Fran Walsh
# 915         Lana Wachowski     Lilly Wachowski        Not Available
# 927    Mark Steven Johnson         Not Available      Not Available
# 1879        Leigh Brackett     Lawrence Kasdan        Not Available
#
#               Writer 4                             Genre  \
# 12634    Not Available                    Drama  SciFi
# 1586     Not Available            Action  SciFi  Drama
# 2318     Not Available         Action  SciFi  Classics
# 1711     Not Available  Action  SciFi  Drama  Classics
# 1609     Not Available   Mystery  Action  SciFi  Drama
# 1183     Not Available         Action  SciFi  Classics
# 255    Peter Jackson    Action  SciFi  Drama  Classics
# 915      Not Available                   Action  SciFi
# 927      Not Available                   Action  SciFi
# 1879     Not Available            Action  SciFi  Drama
#
#                                                 Combined  \
# 12634  Patrik Karlson  Johanna Tschig  Per Lfberg  Ah...
# 1586   Christian Bale  Heath Ledger  Aaron Eckhart  M...
# 2318   Elijah Wood  Sean Astin  Ian McKellen  Andy Se...
# 1711   Elijah Wood  Ian McKellen  Viggo Mortensen  Li...
# 1609   Leonardo DiCaprio  Joseph Gordon-Levitt  Ellen...
# 1183   Richard Benjamin  James Brolin  Yul Brynner  L...
# 255    Elijah Wood  Ian McKellen  Viggo Mortensen  Se...
# 915    Keanu Reeves  Laurence Fishburne  Carrie-Anne ...
# 927    Ben Affleck  Jennifer Garner  Colin Farrell  M...
# 1879   Mark Hamill  Harrison Ford  Carrie Fisher  Ale...
#
#                                                      url  scores
# 12634  https://www.imdb.com/title/tt6290024/?ref_=fn_...     9.5
# 1586   https://www.imdb.com/title/tt0468569/?ref_=fn_...     9.0
# 2318   https://www.imdb.com/title/tt0167260/?ref_=fn_...     8.9
# 1711   https://www.imdb.com/title/tt0120737/?ref_=fn_...     8.8
# 1609   https://www.imdb.com/title/tt1375666/?ref_=fn_...     8.8
# 1183   https://www.imdb.com/title/tt0475784/?ref_=fn_...     8.8
# 255    https://www.imdb.com/title/tt0167261/?ref_=fn_...     8.7
# 915    https://www.imdb.com/title/tt0133093/?ref_=fn_...     8.7
# 927    https://www.imdb.com/title/tt3322312/?ref_=fn_...     8.7
# 1879   https://www.imdb.com/title/tt0080684/?ref_=fn_...     8.7

# %%
x = [movie[movie['Genre'].str.contains('Action') ].sort_values(by='scores')[::-1][:10],movie.sort_values(by='scores')[::-1][:10]]

# %%
df_action[df_action['Director 1'].isin(df_action['Director 1'].value_counts()[:10].index)].groupby('Director 1').mean()
# Out:
#                       scores
# Director 1
# David Cronenberg    6.750000
# Joe Dante           6.412500
# Not Available       6.200000
# Peter Jackson       7.733333
# Ridley Scott        7.300000
# Robert Stevenson    6.825000
# Robert Zemeckis     7.300000
# Steven Spielberg    7.127273
# Terry Gilliam       7.011111
# Tim Burton          6.860000

# %%
x[0]['Title'].iloc[0]
# Out:
# 'A Night to Remember  '
